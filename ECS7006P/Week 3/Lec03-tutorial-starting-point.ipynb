# %% [markdown]
# <h2>Lecture 3 Onset Detection - Tutorial</h2>
# The aim is to prepare for lab 2, where you will implement and test the onset detection functions presented in the lecture. To set this up, we need to be able to:
#  - loop through a set of files
#  - loop through the frames in a file
#  - calculate a simple ODF (in this case RMS energy)
#  - normalise
#  - pick peaks
#  - evaluate (using a given evaluation function)
#  - display results (text and graphs)

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
import librosa
from scipy.signal import medfilt as medfilt
from scipy.ndimage import maximum_filter1d as maxfilt
import sys
sys.path.append('../labs/lab2/')
import evaluate
import IPython.display as ipd


def rms_odf(filename, windowTime, hopTime):
    """Computes a baseline onset detection function using RMS magnitude.
    Parameters:
        filename: path of the input audio file
        windowTime: window size for analysis (in seconds)
        hopTime: hop size (in seconds)
    Returns:
        A vector containing the root mean square magnitude for each frame of audio
    """
    # load audio file
    # convert times to numbers of samples
    # centre frames (first frame centred at t=0)
    # calculate total number of frames
    # initialise ODF
    # initialise window function
    # loop through frames
    # compute RMS energy
    # normalise
    # return ODF


def getOnsets(odf, hopTime, wd=3, thr=0):
    """Performs peak-picking, filtering and thresholding on an onset detection
    function to compute the times of each onset.
    Parameters:
        odf: a vector of onset detection function values, one for each frame
        hopTime: time in seconds between frames of the ODF
        wd: width of filter for median and maximum filtering
        thr: threshold (minimum difference between a peak value and the median
            of the ODF for a peak to be accepted as an onset)
    Returns:
        A vector of onset times in seconds
    """
    # subtract local median
    # calculate max filter (dynamic threshold) for peak picking
    # get index of each peak
    # convert indices to times
    # Plot the ODF and threshold
    # return a vector of onset times


dataDir = '../labs/lab2/data'
windowSize = 
hopSize = 
filterWidth = 
threshold = 
# loop through files
# calculate ODF
# estimate onsets from ODF
# load ground truth onsets
# evaluate
# print statistics of results
        print('Input file: ' + entry.name)
        print('ODF    C  FP  FN   F    Err')
        print('RMS: {:3.0f} {:3.0f} {:3.0f} {:5.3f} {:5.3f}'.format(*results[0]))
# show onsets on plot of ODF
